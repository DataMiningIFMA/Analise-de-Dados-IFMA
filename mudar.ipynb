# %%
import pandas as pd

df = pd.read_excel('dataset.xlsx')

mapeamento = {
    'MTC': 'São Luís-Monte Castelo',
    'REIT': 'Reitoria',
    'MAR': 'São Luís-Maracanã',
    'ITZ': 'Imperatriz',
    'COD': 'Codó',
    'TMN': 'Timon',
    'CCH': 'São Luís-Centro Histórico',
    'ACA': 'Açailândia',
    'CAX': 'Caxias',
    'SIN': 'Santa Inês',
    'BAC': 'Bacabal',
    'SRM': 'São Raimundo das Mangabeiras',
    'SJP': 'São João dos Patos',
    'BAR': 'Barreirinhas',
    'BTC': 'Buriticupu',
    'BDC': 'Barra do Corda',
    'SJR': 'São José de Ribamar',
    'PIN': 'Pinheiro',
    'ZDC': 'Zé Doca',
    'ALC': 'Alcântara',
    'PED': 'Pedreiras',
    'CNT': 'Coelho Neto',
    'GRA': 'Grajaú',
    'VNA': 'Viana',
    'ITA': 'Itapecuru Mirim',
    'ROS': 'Rosário',
    'ARA': 'Araioses',
    'PFR': 'Porto Franco',
    'PDU': 'Presidente Dutra',
    'CLN': 'Carolina',
}

df['Campus de Lotação'] = df['Campus de Lotação'].replace(mapeamento)
print(df)

df.to_excel('C:/Users/there/Documents/Projeto Mineração de Dados/modificado.xlsx', index=False)
# Out:
#          #  Matrícula                                      Nome  \
# 0        1    2037010                  Abel Batista de Oliveira
# 1        2    1829709                   Abias Rodrigues da Cruz
# 2        3    1825579                    Abigail Ferreira Milen
# 3        4    1845623                      Abilio Soares Coelho
# 4        5    1487179                   Abmalena Santos Sanches
# ...    ...        ...                                       ...
# 3776  3777     271426    Zelia Maria de Carvalho Castelo Branco
# 3777  3778    3369157                 Zildiany Ibiapina Meneses
# 3778  3779    1455637                            Zilner Callera
# 3779  3780    2400583  Zilvania Maria Menezes da Silva Pimentel
# 3780  3781     271845             Zoraida de Oliveira Damasceno
#
#                 E-mail para Contato  \
# 0         abel.oliveira@ifma.edu.br
# 1            abias.cruz@ifma.edu.br
# 2         abigail.milen@ifma.edu.br
# 3         abilio.coelho@ifma.edu.br
# ...
